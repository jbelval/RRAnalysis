# %%
import pandas as pd
import matplotlib.pyplot as plt
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as bs

# %%
def get_chapter_content(url):
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    content = bs(urlopen(req).read())
    return content

# %%
get_chapter_content('https://www.royalroad.com/fiction/21220/mother-of-learning/chapter/301778/1-good-morning-brother')
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]> <html lang="en" class="ie8 no-js"> <![endif]--><!--[if IE 9]> <html lang="en" class="ie9 no-js"> <![endif]--><!--[if !IE]><!--><html lang="en">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <title>1. Good Morning Brother - Mother of Learning | Royal Road</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="Mother of Learning;nobody103;1. Good Morning Brother; free books online; web fiction; free; book; novel; royal road; royalroadl; rrl; legends; fiction" name="keywords"/>
# <meta content="Chapter 001Good Morning Brother
# Zorian’s eyes abruptly shot open as a sharp pain erupted from his stomach. His whole body convulsed, buckling against the (...)" name="description"/>
# <meta content="1585608748421060" property="fb:app_id"/>
# <meta content="article" property="og:type"/>
# <meta content="https://www.royalroad.com/fiction/21220/mother-of-learning/chapter/301778/1-good-morning-brother" property="og:url"/>
# <meta content="https://www.royalroadcdn.com/nobody103/mother-of-learning-full-AADAKnUlbAs=.jpg" property="og:image"/>
# <meta content="Royal Road" property="og:site_name"/>
# <meta content="1. Good Morning Brother - Mother of Learning" property="og:title"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@RoyalRoadL" name="twitter:site"/>
# <meta content="nobody103" name="twitter:creator"/>
# <meta content="1. Good Morning Brother - Mother of Learning" name="twitter:title"/>
# <meta content="Chapter 001Good Morning Brother
# Zorian’s eyes abruptly shot open as a sharp pain erupted from his stomach. His whole body convulsed, buckling against the object that fell on him, and suddenly he was wide (...)" name="twitter:description"/>
# <meta content="https://www.royalroadcdn.com/nobody103/mother-of-learning-full-AADAKnUlbAs=.jpg" name="twitter:image"/>
# <link href="/fiction/21220/mother-of-learning/chapter/301781/2-lifes-little-problems" rel="next"/>
# <link href="/Content/Themes/Styles/main-bundle.min.css?v=M2_f0L8sm95nFWB9P0KT8HRoHvYrJqKVi2sNBmdWmzw" rel="stylesheet" type="text/css"/>
# <link href="/Content/fonts/FontAwesome5/css/all.min.css?v=20QNLipyR_tGOzPvjkAzyN7HPHc8Zh2L7cvbmEyTDtA" rel="stylesheet" type="text/css"/>
# <link href="/Content/fonts/FontAwesome5/css/v4-shims.min.css?v=TG1axMd6DNTcroILh6_R7gsYpyvw3Y994Wj9MHrEcEE" rel="stylesheet" type="text/css"/>
# <link href="/Content/Themes/Bootstrap/site.css?v=HMdwClZyiQFaARL4drk2L7ZBBxYMYwzBThqQ7T_hQg8" rel="stylesheet" type="text/css"/>
# <link href="/Content/profile-2.min.css" rel="stylesheet" type="text/css"/>
# <link href="/Content/plugins/socicon/socicon.css" rel="stylesheet" type="text/css"/>
# <link href="/Content/blog.min.css" rel="stylesheet" type="text/css"/>
# <style>
#
#         img.img-offset {
#             margin-top: 20px;
#             margin-bottom: -20px;
#             height: 150px;
#         }
#
#         .vertical-separator {
#             border-left: 1px solid #C1CCD1;
#             margin: auto 6px;
#         }
#
#         .user-stats .btn {
#             text-align: left;
#         }
#
#         @media screen and (min-width: 992px) {
#             .md-text-left {
#                 text-align: left;
#             }
#
#             .fic-buttons {
#                 margin: 20px 0;
#                 min-height: 140px;
#             }
#
#             .profile > .row > .col-md-10 > .row > div {
#                 min-height: 230px;
#             }
#
#             .profile > .row > .col-md-10 > .row .bottom {
#                 position: absolute;
#                 right: 0;
#                 left: 0;
#                 bottom: 0;
#             }
#
#             .user-stats {
#                 width: 100px;
#                 margin: auto
#             }
#         }
#
#         .blog-comments {
#             width: 70%;
#         }
#
#         @media screen and (max-width: 991px) {
#             .fic-buttons {
#                 margin: 10px 0;
#             }
#
#             .blog-comments {
#                 width: 100%;
#             }
#
#             .user-stats .btn {
#                 text-align: center;
#             }
#         }
#
#         .col-bottom {
#             float: none;
#             display: table-cell;
#             vertical-align: bottom;
#         }
#
#         .container {
#             padding-top: 0 !important;
#         }
#
#         @media screen and (min-width: 768px) {
#             .rewind-form {
#                 margin-top: -5px;
#             }
#         }
#     </style>
# <link href="/android-chrome-192x192.png?v=20200125" rel="icon" sizes="192x192"/>
# <link href="/favicon.ico?v=20200125" rel="shortcut icon" sizes="16x16 24x24 32x32"/>
# <link href="/apple-icon-180x180.png?v=20200125" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-16x16.png?v=20200125" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/favicon-32x32.png?v=20200125" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/manifest.json" rel="manifest"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/ms-icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="#FFFFFF" name="theme-color"/>
# <script crossorigin="anonymous" integrity="sha384-r7/ZcDRYpWjCNXLUKk3iuyyyEcDJ+o+3M5CqXP5GUGODYbolXewNHAZLYSJ3ZHcV" src="https://browser.sentry-cdn.com/5.11.1/bundle.min.js"></script>
# <script>
#             Sentry.init({
#                 dsn: 'https://02faebb35f69476494bd985fdf400256@sentry.royalroad.com/3',
#                 release: '4.1.20200224.2',
#                 sampleRate: 0.002,
#                  ignoreErrors: [
#                      // Random plugins/extensions
#                      //'top.GLOBALS',
#                      // See: http://blog.errorception.com/2012/03/tale-of-unfindable-js-error.html
#                      'originalCreateNotification',
#                  ],
#                  whitelistUrls: [
#                      /https?:\/\/((cdn|www)\.)?royalroad\.com/,
#                      /https?:\/\/((cdn|www)\.)?royalroadcdn\.com/,
#                  ]
#             });
#     </script>
# <script src="/Scripts/Plugins/polyfill/object-assign.min.js" type="text/javascript"></script>
# <script src="/Scripts/Plugins/jquery/jquery-2.2.3.min.js" type="text/javascript"></script>
# <script src="/Scripts/Site/locstor.min.js" type="text/javascript">
# </script>
# <script src="/Scripts/Site/global.min.js?v=e9g87yqf9NW9ov7S6mCYA5Gx-20Gf3zWLvKWILt9tyQ" type="text/javascript"></script>
# </head>
# <body class="page-container-bg-solid">
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-49828272-1"></script>
# <script>
#     function createGa() {
#         window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         gtag('js', new Date());
#
#
#     gtag('set', {
#     'dimension1': '21220',
#     'dimension3': '301778'
#     });
#
#         gtag('set', {"dimension5":"NotLoggedIn","dimension6":"NitroPay"});
#
#
#         if (!getCookie("euconsent")) {
#             gtag('set', { 'anonymize_ip': true });
#         }
#
#         gtag('config', 'UA-49828272-1');
#     }
#
#     createGa();
#     </script>
# <script>window.userId = null;</script>
# <script src="/Scripts/showads.js?t=1582766013" type="text/javascript"></script>
# <script src="/Scripts/Site/banner-loader.js?v=AMGVWtSg-wZjwpSHnxgB0H21mCYr1z02_w42VvWSVQ4" type="text/javascript"></script>
# <script type="text/javascript">var AdblockPlus=new function(){this.detect=function(n,e){var o=!1,r=2,c=!1,t=!1;if("function"==typeof e){n+="?ch=*&rn=*";var a=11*Math.random(),i=new Image;i.onload=u,i.onerror=function(){c=!0,u()},i.src=n.replace(/\*/,1).replace(/\*/,a);var f=new Image;f.onload=u,f.onerror=function(){t=!0,u()},f.src=n.replace(/\*/,2).replace(/\*/,a),function n(e,c){0==r||c>1e3?e(0==r&&o):setTimeout(function(){n(e,2*c)},2*c)}(e,250)}function u(){--r||(o=!c&&t)}}};</script><script type="text/javascript">window['nitroAds'] = window['nitroAds'] || { createAd: function () { window.nitroAds.queue.push(["createAd", arguments]) }, queue: [] };</script><script async="async" src="https://s.nitropay.com/ads-137.js" type="text/javascript"></script><script async="async" src="https://s.nitropay.com/aan-137.js" type="text/javascript"></script> <div class="background-overlay"></div>
# <div class="page-header">
# <!-- BEGIN HEADER TOP -->
# <div class="page-header-top">
# <div class="container">
# <!-- BEGIN LOGO -->
# <div class="page-logo">
# <a href="/home">
# <img alt="Royal Road" class="logo-default" src="/Content/Images/logo/rr-logo-gold-white-min.png" title="Royal Road"/>
# </a>
# </div>
# <!-- END LOGO -->
# <!-- BEGIN RESPONSIVE MENU TOGGLER -->
# <a aria-label="Toggle Menu" class="menu-toggler" href="javascript:;" role="button"></a>
# <!-- END RESPONSIVE MENU TOGGLER -->
# <!-- BEGIN TOP NAVIGATION MENU -->
# <div class="top-menu">
# <ul class="nav navbar-nav pull-right">
# <!-- BEGIN NOTIFICATION DROPDOWN -->
# <li class="dropdown dropdown-extended dropdown-notification dropdown-dark" id="header_notification_bar">
# <a aria-label="Notifications" class="dropdown-toggle notifications" data-close-others="true" href="javascript:;">
# <i class="fa fa-bell"></i>
# <span class="badge badge-default alert no-announcement" data-count="0">0</span>
# </a>
# <ul class="dropdown-menu notifications">
# <li class="external">
# <h3>
#                                 You have
#                                 <strong><span class="no-announcement">no</span> pending</strong> notifications
#                             </h3>
# <a href="/notifications/list">View all</a>
# </li>
# <li>
# <ul class="dropdown-menu-list scroller" data-handle-color="#637283" style="height: 250px;">
# <li style="overflow: hidden">
# <div class="loader spinner">Loading...</div>
# </li>
# </ul>
# </li>
# <li class="font-sm text-center external">
# </li>
# </ul>
# </li>
# <!-- END NOTIFICATION DROPDOWN -->
# <li>
# <a href="https://www.royalroad.com/account/login?returnUrl=https%3A%2F%2Fwww.royalroad.com%2Ffiction%2F21220%2Fmother-of-learning%2Fchapter%2F301778%2F1-good-morning-brother">
# <i class="icon-login"></i> Log In
#                         </a>
# </li>
# </ul>
# </div>
# <!-- END TOP NAVIGATION MENU -->
# </div>
# </div>
# <!-- END HEADER TOP -->
# <div class="page-header-menu">
# <div class="container">
# <form action="/fictions/search" class="search-form" method="GET">
# <div class="input-group">
# <input aria-label="Fiction search" class="form-control" name="title" placeholder="Search" type="text"/>
# <span class="input-group-btn">
# <a aria-label="Search" class="btn submit" href="javascript:;" role="button">
# <i class="icon-magnifier"></i>
# </a>
# <a aria-label="Advanced Search" class="btn btn-icon-only btn-primary popovers adv-search" data-container="body" data-content="Advanced Search" data-placement="bottom" data-trigger="hover" href="/fictions/search?advanced=True">
# <i class="fa fa-list"></i>
# </a>
# </span>
# </div>
# </form>
# <div class="hor-menu">
# <ul class="nav navbar-nav">
# <li class="dropdown menu-dropdown classic-menu-dropdown">
# <a aria-expanded="false" aria-haspopup="true" aria-label="Read" class="dropdown-toggle" data-toggle="dropdown" href="javascript:;" role="button">
# <i class="fa fa-book"></i> Read
#                         <span class="arrow"></span>
# </a>
# <ul class="dropdown-menu pull-left">
# <li class="">
# <a class="nav-link" href="/fictions/best-rated">
# <i class="fa fa-trophy"></i> Best Rated
#                                 </a>
# </li>
# <li class="">
# <a class="nav-link" href="/fictions/active-popular">
# <i class="fa fa-fire"></i> Active-only ranking
#                                 </a>
# </li>
# <li class="">
# <a class="nav-link" href="/fictions/complete">
# <i class="fa fa-flag-checkered"></i> Complete
#                                 </a>
# </li>
# <li class="">
# <a class="nav-link" href="/fictions/weekly-popular">
# <i class="fa fa-chart-line"></i> Popular this week
#                                 </a>
# </li>
# <li class="">
# <a class="nav-link" href="/fictions/latest-updates">
# <i class="fa fa-clock"></i> Latest Updates
#                                 </a>
# </li>
# <li class="">
# <a class="nav-link" href="/fictions/new-releases">
# <i class="fa fa-sync"></i> New Releases
#                                 </a>
# </li>
# <li class="">
# <a class="nav-link" href="/fictions/trending">
# <i class="fa fa-chevron-up"></i> Trending
#                                 </a>
# </li>
# <li class="">
# <a class="nav-link" href="/fictions/search">
# <i class="fa fa-search"></i> Search
#                                 </a>
# </li>
# <li class="">
# <a class="nav-link" href="/fiction/random">
# <i class="fa fa-random"></i> Surprise me!
#                                 </a>
# </li>
# </ul>
# </li>
# <li class="dropdown menu-dropdown classic-menu-dropdown">
# <a aria-label="Write" href="/my/fictions" role="link">
# <i class="fa fa-pencil"></i> Write
#                 </a>
# </li>
# <li class="dropdown menu-dropdown classic-menu-dropdown">
# <a aria-label="Forums" href="/forums" role="link">
# <i class="fa fa-comments"></i> Forums
#                 </a>
# </li>
# <li class="dropdown menu-dropdown classic-menu-dropdown">
# <a aria-label="Member List" href="/user/memberlist" role="link">
# <i class="fa fa-users"></i> Member List
#                 </a>
# </li>
# <li class="dropdown menu-dropdown classic-menu-dropdown">
# <a aria-expanded="false" aria-haspopup="true" aria-label="Support" class="dropdown-toggle" data-toggle="dropdown" href="javascript:;" role="button">
# <i class="fas fa-life-ring"></i> Support
#                         <span class="arrow"></span>
# </a>
# <ul class="dropdown-menu pull-left">
# <li class="">
# <a class="nav-link" href="/support/faq">
# <i class="fa fa-list"></i> F.A.Q.
#                                 </a>
# </li>
# <li class="">
# <a class="nav-link" href="https://feedback.royalroad.com/s1-general/ideas">
# <i class="fa fa-lightbulb"></i> Suggestions
#                                 </a>
# </li>
# <li class="">
# <a class="nav-link" href="https://www.royalroad.com/forums/1124">
# <i class="fa fa-users"></i> Community Help
#                                 </a>
# </li>
# <li class="">
# <a class="nav-link" href="/support">
# <i class="fas fa-user-headset"></i> Help Desk
#                                 </a>
# </li>
# <li class="">
# <a class="nav-link" href="https://status.royalroad.com">
# <i class="fa fa-check-circle"></i> Status
#                                 </a>
# </li>
# </ul>
# </li>
# <li class="dropdown menu-dropdown classic-menu-dropdown">
# <a aria-label="Premium" href="/premium" role="link">
# <i class="fa fa-star"></i> Premium
#                 </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="page-container">
# <div class="page-content-wrapper">
# <div class="page-content">
# <div class="container">
# <div class="row fic-header margin-bottom-40">
# <div class="row no-space">
# <div class="col-md-2 col-md-push-1 hidden-sm hidden-xs">
# <img alt="Mother of Learning" class="img-offset" id="cover-Mother of Learning-3733C2938DBA5B6E" onerror="this.onerror=null; this.src='/Content/Images/nocover-new-min.png';" src="https://www.royalroadcdn.com/nobody103/mother-of-learning-full-AADAKnUlbAs=.jpg"/>
# </div>
# <div class="col-md-5 col-lg-6 col-md-offset-1 text-center md-text-left">
# <a href="/fiction/21220/mother-of-learning">
# <h2 class="font-white inline-block" style="font-size: 24px">Mother of Learning</h2>
# </a><span class="font-white"> by </span><h3 class="font-white inline-block" style="font-size: 21px"><a class="font-white" href="/profile/100374">nobody103</a></h3> <h4 class="font-red-thunderbird star star-48"></h4>
# <h1 class="font-white" style="margin-top: 10px">1. Good Morning Brother</h1>
# </div>
# <div class="col-md-4 col-lg-3 fic-buttons text-center md-text-left">
# <a class="btn btn-block btn-primary margin-bottom-5" href="/fiction/21220/mother-of-learning"><i class="fa fa-book"></i> Fiction Page</a>
# <div class="btn-group" style="width: 100%">
# <a aria-expanded="false" class="btn btn-block btn-default popovers margin-bottom-5 dropdown-toggle" data-container="body" data-content="All donations to the authors go through their own PayPal or Patreon account; Royal Road takes absolutely no part of your donations." data-original-title="Donations" data-placement="top" data-toggle="dropdown" data-trigger="hover" href="javascript:;"><i class="fa fa-money font-dark"></i> Donate</a>
# <ul class="dropdown-menu" style="width: 100%">
# <li>
# <a href="https://www.patreon.com/nobody103"><i class="socicon socicon-patreon"></i> Patreon</a>
# </li>
# </ul>
# </div>
# <a class="btn btn-block red-thunderbird margin-bottom-5" href="/report/chapter/301778"><i class="fas fa-exclamation-triangle"></i> Report</a>
# </div>
# </div>
# </div>
# <div class="portlet light text-center" style="padding-top: 5px !important;position: relative">
# <h6 class="bold uppercase">Advertisement</h6>
# <span style="position: absolute; top: 10px;right:10px"><a class="btn btn-default btn-xs" href="/premium/subscription" target="_blank"><i class="fa fa-times"></i> Remove <span class="hidden-xs">Ads</span></a></span>
# <div class="wide text-center">
# <div id="Content_Top_Desktop"></div>
# <div id="Content_Top_Mobile"></div>
# </div>
# </div>
# <div class="portlet light chapter">
# <div class="portlet-title">
# <div class="caption">
# </div>
# <div class="actions">
# <a class="btn btn-circle red visible-xs" data-toggle="modal" href="#settings">
# <i class="fa fa-cog"></i> Settings
#             </a>
# <div class="hidden-xs text-right">
# <a class="btn btn-circle dark" href="/skin?skin=dark&amp;returnurl=https%3A%2F%2Fwww.royalroad.com%2Ffiction%2F21220%2Fmother-of-learning%2Fchapter%2F301778%2F1-good-morning-brother" onclick="setStyle(event, 'dark')">
# <i class="fa fa-eye"></i> Dark Theme
#                     </a>
# <span class="vertical-separator"></span>
# <label for="reader-width">Width</label>
# <span>
# <select class="reader-width form-control btn btn-default btn-circle input-xsmall" id="reader-width">
# <option selected="selected" value="max">Max</option>
# <option value="90">90%</option>
# <option value="80">80%</option>
# <option value="70">70%</option>
# <option value="60">60%</option>
# <option value="50">50%</option>
# </select>
# </span>
# <span class="vertical-separator"></span>
# <select class="font-size form-control btn btn-default btn-circle input-xsmall">
# <option value="12">12px</option>
# <option value="14">14px</option>
# <option selected="selected" value="16">16px</option>
# <option value="18">18px</option>
# <option value="20">20px</option>
# <option value="22">22px</option>
# <option value="24">24px</option>
# <option value="28">28px</option>
# <option value="32">32px</option>
# </select>
# <span>
# <select class="font-family form-control btn btn-default btn-circle input-small">
# <option selected="selected" style="font-family: Helvetica Neue, Helvetica, Roboto, Arial, sans-serif" value="Helvetica Neue, Helvetica, Roboto, Arial, sans-serif">Default</option>
# <option style="font-family: Arial" value="Arial">Arial</option>
# <option style="font-family: Roboto" value="Roboto">Roboto</option>
# <option style="font-family: Comic Sans" value="Comic Sans">Comic Sans</option>
# <option style="font-family: Segoe UI" value="Segoe UI">Segoe UI</option>
# <option style="font-family: Verdana" value="Verdana">Verdana</option>
# <option style="font-family: Ubuntu" value="Ubuntu">Ubuntu</option>
# <option style="font-family: Ubuntu Condensed" value="Ubuntu Condensed">Ubuntu Condensed</option>
# <option style="font-family: Franklin Gothic" value="Franklin Gothic">Franklin Gothic</option>
# <option style="font-family: Garamond" value="Garamond">Garamond</option>
# <option style="font-family: Caslon" value="Caslon">Caslon</option>
# <option style="font-family: Minion" value="Minion">Minion</option>
# </select>
# </span>
# <label class="mt-checkbox" for="font-override"><input class="font-override" id="font-override" type="checkbox"/>Override<span></span></label>
# <span class="vertical-separator"></span>
# <label for="dim-dropdown">Dim BG</label>
# <span>
# <select class="dim-dropdown form-control btn btn-default btn-circle input-xsmall" id="dim-dropdown" name="dim-dropdown"><option selected="selected" value="0">0%</option>
# <option value="0.2">20%</option>
# <option value="0.4">40%</option>
# <option value="0.5">50%</option>
# <option value="0.6">60%</option>
# <option value="0.8">80%</option>
# <option value="1">100%</option>
# </select>
# </span>
# </div>
# </div>
# </div>
# <div class="portlet-body">
# <div class="row nav-buttons">
# <div class="col-xs-6 col-md-4 col-lg-3 col-xl-2">
# <button class="btn btn-primary col-xs-12" disabled="disabled">
# <i class="far fa-chevron-double-left mr-3"></i> Previous <br class="visible-xs-block"/>Chapter
#                     </button>
# </div>
# <div class="col-xs-6 col-md-4 col-md-offset-4 col-lg-3 col-lg-offset-6">
# <p>His father always joked that Fortov and Zorian each got a half of Daimen in them: Fortov got his charm, and Zorian his competence.</p>
# <p>Zorian had never liked his father’s sense of humor.</p>
# <p>A whistle pierced the air, and the train entered the station with a high-pitched squeal of metal wheels braking against the tracks. The original trains were steam-powered machines that billowed smoke wherever they went and consumed unholy amounts of coal to keep going, but this one was powered by the newer techno-magic engines that consumed crystallized mana instead. Cleaner, cheaper, and required less maintenance. Zorian could actually feel the mana radiating off the train as he approached, though his ability to sense magic was too underdeveloped to tell him any details. He had always wanted to look around the engine room of one of these things but could never figure out a good way to approach the train operators.</p>
# <p>But that was a thought for another time. He gave a brief goodbye to Mother and Kirielle and entered the train to find himself a seat. He intentionally chose an empty compartment, something that was surprisingly easy to find. Apparently, despite the gathered crowd, few of them would be taking this particular train.</p>
# <p>Five minutes later, the train gave another ear-splitting whistle and began its long journey towards Cyoria.</p>
# <p style="text-align: center">* * *</p>
# <p>There was a sharp crackling sound, following by the sound of a bell ringing.</p>
# <p>“Now stopping in Korsa,” a disembodied voice echoed. A crackling sound again. “I repeat, now stopping in Korsa. Thank you.”</p>
# <p>The speakers crackled one last time before turning silent.</p>
# ...
# <option style="font-family: Franklin Gothic" value="Franklin Gothic">Franklin Gothic</option>
# <option style="font-family: Garamond" value="Garamond">Garamond</option>
# <option style="font-family: Caslon" value="Caslon">Caslon</option>
# <option style="font-family: Minion" value="Minion">Minion</option>
# </select>
# </div>
# <div class="col-xs-4 col-md-3" style="padding: 0.5rem">
# <label class="mt-checkbox" for="font-override2"><input class="font-override" id="font-override2" type="checkbox"/>Override<span></span></label>
# </div>
# </div>
# </div>
# <div class="form-group">
# <label>Dim background</label>
# <select class="dim-dropdown form-control" id="dim-dropdown" name="dim-dropdown"><option selected="selected" value="0">0%</option>
# <option value="0.2">20%</option>
# <option value="0.4">40%</option>
# <option value="0.5">50%</option>
# <option value="0.6">60%</option>
# <option value="0.8">80%</option>
# <option value="1">100%</option>
# </select>
# </div>
# </div>
# </div>
# <div class="modal-footer">
# <button class="btn dark btn-outline" data-dismiss="modal" type="button">Close</button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="rep-modal" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="portlet">
# <form action="/forums/givereputation" class="form" id="give-reputation-form" method="post">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <h4 class="modal-title">Give Reputation to User: <span id="rep-username"></span></h4>
# </div>
# <div class="modal-body">
# <input id="rep-uid" name="uid" type="hidden"/>
# <input id="rep-cid" name="cid" type="hidden"/>
# <div class="form-group">
# <label class="control-label" for="amount">Points</label>
# <input class="form-control" id="rep-amount" max="0" min="0" name="amount" type="number" value="0"/>
# <span class="hint small" id="rep-hint">You can specify how many points you want to give (minimum: 0, maximum: 0).</span>
# </div>
# <div class="form-group">
# <label class="control-label" for="c">Comment <small>(optional)</small></label>
# <textarea class="form-control" id="c" name="comment" rows="3" type="text"></textarea>
# <span class="hint small">Why are you giving this user reputation?</span>
# </div>
# </div>
# <div class="modal-footer">
# <button class="btn btn-primary" type="submit">Give Reputation</button>
# <button class="btn dark btn-outline" data-dismiss="modal" type="button">Close</button>
# </div>
# </div>
# <input name="__RequestVerificationToken" type="hidden" value="CfDJ8BHZuYCzNRVKq6624WbOlfRVjgk2i9OZlzfaypwhTejOjpNuTVxgIYU3ZyJMss-SdVpqiQNOeVZ3-WWZucz1DxKTFv48rq0asKiXO51xQAAdOZOvDmLDFBESJil5Hx3ZihNcWMtokX3cFLIkb3uDTjU"/></form>
# </div>
# <div id="rep-modal-loader" style="position: absolute; top: 0; left: 0; bottom: 0; right: 0; background: rgba(0, 0, 0, .5); display: none">
# <div style="position: absolute; left: calc(50% - 40px); top: calc(50% - 140px);">
# <div class="loading spinner"><div class="cube1 bg-blue"></div><div class="cube2 bg-blue"></div></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="page-prefooter">
# <div class="container">
# <div class="row">
# <div class="col-md-3 col-sm-6 col-xs-12 footer-block">
# <h2>About</h2>
# <p> Royal Road® is the home of web novels and fan fictions! In our amazing community, you can find various talented individuals who write as a hobby or even professionally, artists who create art for them, and many, many readers who provide valuable feedback and encouragement. </p>
# </div>
# <div class="col-md-3 col-sm-6 col-xs12 footer-block">
# <h2>Amazon Affiliate</h2>
# <div class="smalltext">
#                             Royal Road® is a participant in the Amazon Services LLC Associates Program, an affiliate advertising program designed to provide a means for sites to earn advertising fees by advertising and linking to amazon.com.
#                         </div>
# </div>
# <div class="col-md-3 col-sm-6 col-xs-12 footer-block">
# <h2>
# <label for="style" style="font-weight: inherit; color: inherit">Theme Select</label>
# </h2>
# <div class="subscribe-form">
# <select class="style-select form-control" id="style" name="style">
# <option value="dark">Dark</option>
# <option selected="selected" value="light">Light</option>
# </select>
# </div>
# <br/>
# <h2>Follow Us On</h2>
# <ul class="social-icons">
# <li>
# <a aria-label="Our Facebook Page" class="facebook" data-original-title="facebook" href="https://facebook.com/royalroadl" rel="noopener noreferrer" target="_blank"></a>
# </li>
# <li>
# <a aria-label="Our Twitter Page" class="twitter" data-original-title="twitter" href="https://twitter.com/royalroadl" rel="noopener noreferrer" target="_blank"></a>
# </li>
# </ul>
# </div>
# <!--sse-->
# <div class="col-md-3 col-sm-6 col-xs-12 footer-block">
# <h2>Need some help?</h2>
# <div>
# <a href="/support">Create a support ticket</a>
# </div>
# <div>
# <span data-ccpa-link="1"></span>
# </div>
# <br/>
# <h2>Contact</h2>
# <a href="/contact">Contact Us</a>
# <br/>
# </div>
# <!--/sse-->
# </div>
# </div>
# </div>
# <!-- END PRE-FOOTER -->
# <!-- BEGIN INNER FOOTER -->
# <div class="page-footer footer">
# <div class="container">
# <div class="pull-left">
#                 Royal Road® © 2013-2020, background by <a href="https://noahbradley.com/" rel="noopener" target="_blank">Noah Bradley</a>
# </div>
# <div class="pull-right">
# <a href="/tos">Terms of Service</a> |
#                 <a class="iubenda-nostyle no-brand iubenda-embed" href="https://www.iubenda.com/privacy-policy/8009648" title="Privacy Policy">Privacy Policy</a> |
#                 <a class="iubenda-nostyle no-brand iubenda-embed" href="https://www.iubenda.com/privacy-policy/8009648/cookie-policy" title="Cookie Policy">Cookie Policy</a> |
#                 <a href="/blog">Blog</a> |
#                 <a href="https://status.royalroad.com">Status</a>
# <script type="text/javascript">
#     (function (w, d) {
#                         var loader = function () {
#                             var s = d.createElement("script"), tag = d.getElementsByTagName("script")[0];
#                             s.src = "//cdn.iubenda.com/iubenda.js";
#                             tag.parentNode.insertBefore(s, tag);
#                         };
#                         if (w.addEventListener) {
#                             w.addEventListener("load", loader, false);
#                         } else if (w.attachEvent) {
#                             w.attachEvent("onload", loader);
#                         } else {
#                             w.onload = loader;
#                         }
#                     })(window, document);
#                 </script>
# <script type="text/javascript">
#                     (function (w, d) {
#                         var loader = function () {
#                             var s = d.createElement("script"), tag = d.getElementsByTagName("script")[0];
#                             s.src = "https://cdn.iubenda.com/iubenda.js";
#                             tag.parentNode.insertBefore(s, tag);
#                         };
#                         if (w.addEventListener) {
#                             w.addEventListener("load", loader, false);
#                         } else if (w.attachEvent) {
#                             w.attachEvent("onload", loader);
#                         } else {
#                             w.onload = loader;
#                         }
#                     })(window, document);
#                 </script>
# </div>
# </div>
# </div>
# <div class="scroll-to-top">
# <i class="icon-arrow-up"></i>
# </div>
# <!--[if lt IE 9]>
#         <script type="text/javascript" src="~/Scripts/Plugins/ie8/respond.min.js"></script>
#         <script type="text/javascript" src="~/Scripts/Plugins/ie8/excanvas.min.js"></script>
#     <![endif]-->
# <script src="/Scripts/Plugins/bootstrap/bootstrap.min.js" type="text/javascript"></script>
# <script src="/Scripts/Plugins/js.cookie/js.cookie.min.js" type="text/javascript"></script>
# <script src="/Scripts/Plugins/bootstrap-hover-dropdown/bootstrap-hover-dropdown.js" type="text/javascript"></script>
# <script src="/Scripts/Plugins/jquery-blockui/jquery.blockui.min.js" type="text/javascript"></script>
# <script src="/Scripts/Plugins/bootstrap-switch/bootstrap-switch.js" type="text/javascript"></script>
# <script src="/Scripts/Plugins/sweetalert/sweetalert.min.js" type="text/javascript"></script>
# <script src="/Scripts/Site/app.min.js?v=xlGFyW2NM4_Dv5wiDAYETg0ysO3MnwI6lSQNAOnOCBE" type="text/javascript"></script>
# <script src="/Scripts/Site/layout.min.js?v=lrgt2sykNLwMxocUdw0l786W2Q7qbmP7F8wHIeaDvvU" type="text/javascript"></script>
# <script>
#
#         function AdBlockEnabled() {
#             var ad = document.createElement('ins');
#             ad.className = 'AdSense';
#             ad.style.display = 'block';
#             ad.style.position = 'absolute';
#             ad.style.top = '-1px';
#             ad.style.height = '1px';
#             document.body.appendChild(ad);
#             var isAdBlockEnabled = !ad.clientHeight;
#             document.body.removeChild(ad);
#             return isAdBlockEnabled;
#         }
#     </script>
# <script>
# </script>
# <script type="text/javascript">
#     $(document).ready(function() {
#     });
#     </script>
# <script src="https://ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js"></script>
# <script>
#         WebFont.load({
#             google: {
#                 families: ['Ubuntu', 'Ubuntu Condensed', 'Open Sans:300,400,600,700']
#             }
#         });
#     </script>
# <script src="/Scripts/Plugins/polyfill/intersection-observer.min.js" type="text/javascript"></script>
# <script>(window.IntersectionObserver||document.write("\u003Cscript type=\u0022text/javascript\u0022 src=\u0022/Scripts/Plugins/polyfill/intersection-observer.js\u0022\u003E\u003C/script\u003E"));</script>
# <script src="/Scripts/Plugins/jquery-pulsate/jquery.pulsate.min.js" type="text/javascript"></script>
# <script src="/Scripts/Site/fiction-reader.min.js?v=eBs_0AEuNG6G71I_EIIWpni_W4fLk0CMfrrQi3XKTcs" type="text/javascript"></script>
# <script>
#             var chapterId = 301778;
#             //window.twttr = (function (d, s, id) {
#             //    var js, fjs = d.getElementsByTagName(s)[0],
#             //        t = window.twttr || {};
#             //    if (d.getElementById(id)) return t;
#             //    js = d.createElement(s);
#             //    js.id = id;
#             //    js.src = "https://platform.twitter.com/widgets.js";
#             //    fjs.parentNode.insertBefore(js, fjs);
#
#             //    t._e = [];
#             //    t.ready = function (f) {
#             //        t._e.push(f);
#             //    };
#
#             //    return t;
#             //}(document, "script", "twitter-wjs"));
#
#     </script>
# <script src="/Scripts/Plugins/tinymce5/tinymce.min.js" type="text/javascript"></script>
# <script>
#         function loadEditor(selector)
#         {
#             var tiny_settings = {
#                 selector: selector,
#                 statusbar: false,
#                 mentions: {
#                     source: function (query, process, delimiter) {
#                         // Do your ajax call
#                         // When using multiple delimiters you can alter the query depending on the delimiter used
#                         $.getJSON('/user/search', {username: query}, function (data) {
#                             //call process to show the result
#                             process(data)
#                         });
#                     },
#                     highlighter: function(text) {
#                         //make matched block italic
#                         return text.replace(new RegExp('(@' + this.query + ')', 'ig'), function ($1, match) {
#                             return '<em>' + match + '</em>';
#                         });
#                     },
#                     insert: function(item) {
#                         return '<a href="/profile/'+item.id+'">@' + item.name + '</a>';
#                     }
#                 }
#             };
#             tinymce.init(Object.assign(Object.assign({"fontsize_formats":"0.8em 0.9em 1.0em 1.1em 1.3em 1.5em 1.8em 2.0em 2.5em 3.0em","menubar":false,"relative_urls":false,"convert_urls":false,"branding":false,"cache_suffix":"?v=4.20200117.1","min_height":120,"max_height":500,"width":"100%","autoresize_bottom_margin":0,"invalid_elements":"pre","contextmenu":false}, {
#             selector: "",
#             plugins: "code fullscreen link paste image link emoticons spoiler mention lists autoresize",
#             skin: "rr-light",
#             content_css: "default",
#             toolbar: ["undo redo | bold italic underline strikethrough | removeformat forecolor | emoticons | hr spoiler blockquote | link image | bullist numlist | fullscreen code"],
#         }), tiny_settings));
#         }
#         loadEditor("textarea#comment");
#         loadEditor("textarea#comment2");
#     </script>
# <script type="text/javascript">if(window.innerWidth >= 991) {window['nitroAds'].createAd('Content_Top_Desktop', {
#   "floor": 0.05,
#   "refreshLimit": 3,
#   "refreshTime": 300,
#   "report": {
#     "enabled": true,
#     "wording": "Report Ad",
#     "position": "fixed-bottom-right"
#   },
#   "sizes": [
#     [
#       728,
#       90
#     ]
#   ],
#   "renderVisibleOnly": false,
#   "refreshVisibleOnly": false,
#   "acceptable": false
# });}
# if(window.innerWidth >= 991) {window['nitroAds'].createAd('Content_Top_Desktop', {
#   "floor": 0.05,
#   "report": {
#     "enabled": true,
#     "wording": "Report Ad",
#     "position": "fixed-bottom-right"
#   },
#   "sizes": [
#     [
#       728,
#       90
#     ]
#   ],
#   "renderVisibleOnly": false,
#   "refreshVisibleOnly": false,
#   "acceptable": true
# });}
# if(window.innerWidth < 991) {window['nitroAds'].createAd('Content_Top_Mobile', {
#   "floor": 0.05,
#   "refreshLimit": 3,
#   "refreshTime": 300,
#   "report": {
#     "enabled": true,
#     "wording": "Report Ad",
#     "position": "fixed-bottom-right"
#   },
#   "sizes": [
#     [
#       320,
#       50
#     ]
#   ],
#   "renderVisibleOnly": false,
#   "refreshVisibleOnly": false,
#   "acceptable": false
# });}
# if(window.innerWidth < 991) {window['nitroAds'].createAd('Content_Top_Mobile', {
#   "floor": 0.05,
#   "report": {
#     "enabled": true,
#     "wording": "Report Ad",
#     "position": "fixed-bottom-right"
#   },
#   "sizes": [
#     [
#       320,
#       50
#     ]
#   ],
#   "renderVisibleOnly": false,
#   "refreshVisibleOnly": false,
#   "acceptable": true
# });}
# window['nitroAds'].createAd('Content_Mid_Desktop', {
#   "floor": 0.05,
#   "refreshLimit": 3,
#   "refreshTime": 300,
#   "report": {
#     "enabled": true,
#     "wording": "Report Ad",
#     "position": "fixed-bottom-right"
#   },
#   "sizes": [
#     [
#       300,
#       250
#     ],
#     [
#       728,
#       90
#     ]
#   ],
#   "renderVisibleOnly": false,
#   "refreshVisibleOnly": false,
#   "acceptable": false
# });
# window['nitroAds'].createAd('Content_Mid_Desktop', {
#   "floor": 0.05,
#   "report": {
#     "enabled": true,
#     "wording": "Report Ad",
#     "position": "fixed-bottom-right"
#   },
#   "sizes": [
#     [
#       300,
#       250
#     ],
#     [
#       728,
#       90
#     ]
#   ],
#   "renderVisibleOnly": false,
#   "refreshVisibleOnly": false,
#   "acceptable": true
# });
# window['nitroAds'].createAd('Content_Bottom_Desktop', {
#   "floor": 0.05,
#   "refreshLimit": 3,
#   "refreshTime": 300,
#   "report": {
#     "enabled": true,
#     "wording": "Report Ad",
#     "position": "fixed-bottom-right"
#   },
#   "sizes": [
#     [
#       300,
#       250
#     ],
#     [
#       728,
#       90
#     ]
#   ],
#   "renderVisibleOnly": false,
#   "refreshVisibleOnly": false,
#   "acceptable": false
# });
# window['nitroAds'].createAd('Content_Bottom_Desktop', {
#   "floor": 0.05,
#   "report": {
#     "enabled": true,
#     "wording": "Report Ad",
#     "position": "fixed-bottom-right"
#   },
#   "sizes": [
#     [
#       300,
#       250
#     ],
#     [
#       728,
#       90
#     ]
#   ],
#   "renderVisibleOnly": false,
#   "refreshVisibleOnly": false,
#   "acceptable": true
# });
# </script>
# </body>
# </html>
# <!--
#       ___               _   ___              _
#      | _ \___ _  _ __ _| | | _ \___  __ _ __| |
#      |   / _ \ || / _` | | |   / _ \/ _` / _` |
#      |_|_\___/\_, \__,_|_| |_|_\___/\__,_\__,_|
#               |__/
#     -->
